# %% [markdown]
# # Curso de Machine Learning Aplicado con Python

# %% [markdown]
# ![Machine-Learning](assets/Machine-Learning.jpg)

# %% [markdown]
# Podemos encontrar mas datasets en https://www.kaggle.com/datasets

# %% [markdown]
# Las librerías con las que vamos a trabajar y que tenemos que cargar son:
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib.pyplot
# 4. Seaborn

# %%
# importamos las librerias
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
print("""
Version Numpy:     \t{} 
Version Pandas:    \t{} 
Version Matplotlib:\t{}
Version seaborn:   \t{}""".format(np.__version__,pd.__version__,matplotlib.__version__,sb.__version__))
# Out:
# Version Numpy:     	1.13.1
# Version Pandas:    	0.20.3
# Version Matplotlib:	2.0.2
# Version seaborn:   	0.8.0

# %%
# Esta linea permite que los graficos sean renderizados directamente en nuestro Notebook
# %matplotlib inline

# %% [markdown]
# ## Carguemos  en un pandas dataframe nuestra base de datos

# %% [markdown]
# `pd.read_csv` es el metodo que nos permite importar los datos desde un CSV y cargarlo en un **DataFrame**, que es la estructura de base de Pandas

# %%
movies = pd.read_csv('IMDb_dataset.csv', delimiter=';', encoding='utf-8')

# %%
type(movies) # Esto es de tipo dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
movies.head()['movie_title']
# Out:
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
movies.query('movie_title == "Avatar"')
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0         79         178.0
#
#   movie_facebook_likes
# 0                33000
#
# [1 rows x 28 columns]

# %%
movies['movie_title']
# Out:
# 0                                                  Avatar
# 1                Pirates of the Caribbean: At World's End
# 2                                                 Spectre
# 3                                   The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
# 5                                             John Carter
# 6                                            Spider-Man 3
# 7                                                 Tangled
# 8                                 Avengers: Age of Ultron
# 9                  Harry Potter and the Half-Blood Prince
# 10                     Batman v Superman: Dawn of Justice
# 11                                       Superman Returns
# 12                                      Quantum of Solace
# 13              Pirates of the Caribbean: Dead Mans Chest
# 14                                        The Lone Ranger
# 15                                           Man of Steel
# 16               The Chronicles of Narnia: Prince Caspian
# 17                                           The Avengers
# 18            Pirates of the Caribbean: On Stranger Tides
# 19                                         Men in Black 3
# 20              The Hobbit: The Battle of the Five Armies
# 21                                 The Amazing Spider-Man
# 22                                             Robin Hood
# 23                    The Hobbit: The Desolation of Smaug
# 24                                     The Golden Compass
# 25                                              King Kong
# 26                                                Titanic
# 27                             Captain America: Civil War
# 28                                             Battleship
# 29                                         Jurassic World
#                               ...
# 5013                                               Manito
# 5014                                              Rampage
# 5015                                              Slacker
# 5016                                          Dutch Kills
# 5017                                            Dry Spell
# 5018                                             Flywheel
# 5019                                               Exeter
# 5020                                           The Ridges
# 5021                                      The Puffy Chair
# 5022                                 Stories of Our Lives
# 5023                                     Breaking Upwards
# 5024                             All Superheroes Must Die
# 5025                                       Pink Flamingos
# 5026                                                Clean
# 5027                                           The Circle
# 5028                                          Tin Can Man
# 5029                                             The Cure
# 5030                                       On the Downlow
# 5031                         Sanctuary; Quite a Conundrum
# 5032                                                 Bang
# 5033                                               Primer
# 5034                                               Cavite
# 5035                                          El Mariachi
# 5036                                      The Mongol King
# 5037                                            Newlyweds
# 5038                              Signed Sealed Delivered
# 5039                            The Following
# 5040                                 A Plague So Pleasant
# 5041                                     Shanghai Calling
# 5042                                    My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
#Que dimensiones tiene nuestro dataset
movies.shape
# Out:
# (5043, 28)

# %% [markdown]
# ## Varios de los comandos utiles para pandas podemos encontrarlos [aquí](https://github.com/WillArevalo/Big-Data-and-Data-Science/blob/master/pandas-cheat-sheet.pdf)

# %%
#Nombres de las columnas
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#Accedemos al index de las filas 
movies.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
#Accediendo a una columna 
columna1 = movies['movie_title']
columna1.head()
# Out:
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
#Accediendo a una fila
linea1 = movies.loc[10,:]
linea1
# Out:
# color                                                                    Color
# director_name                                                      Zack Snyder
# num_critic_for_reviews                                                     673
# duration                                                                   183
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                    2000
# actor_2_name                                                      Lauren Cohan
# actor_1_facebook_likes                                                   15000
# gross                                                              3.30249e+08
# genres                                                 Action|Adventure|Sci-Fi
# actor_1_name                                                      Henry Cavill
# movie_title                                 Batman v Superman: Dawn of Justice
# num_voted_users                                                         371639
# cast_total_facebook_likes                                                24450
# actor_3_name                                                    Alan D. Purwin
# facenumber_in_poster                                                         0
# plot_keywords                based on comic book|batman|sequel to a reboot|...
# movie_imdb_link              http://www.imdb.com/title/tt2975590/?ref_=fn_t...
# num_user_for_reviews                                                      3018
# language                                                               English
# country                                                                    USA
# content_rating                                                           PG-13
# budget                                                                 2.5e+08
# title_year                                                                2016
# actor_2_facebook_likes                                                    4000
# imdb_score                                                                  69
# aspect_ratio                                                               235
# movie_facebook_likes                                                    197000
# Name: 10, dtype: object

# %% [markdown]
# ## Inspección de los tipos de datos
#
# ### Datos importantes:
#
# * La **inspección de los datos** se da para tener conocimiento de la salud de los datos que tenemos, saber si vienen limpios o no, y también porque se quiere tener un entendimiento cuantitativo de ellos. Parte de esto es mirar gráficos estadísticos y entender diferentes propiedades numéricas de las columnas.
# * A diferencia de **Numpy, Pandas** no solo permite cargar datos numéricos, sino también datos de texto.
# * El método info nos va a mostrar la cantidad completa de columnas con la cantidad de elementos no nulos que hay en esas columnas, y por último muestra el tipo de cada columna.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# plot_keywords                4890 non-null object
# movie_imdb_link              5043 non-null object
# num_user_for_reviews         5022 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# content_rating               4740 non-null object
# budget                       4551 non-null float64
# title_year                   4935 non-null float64
# actor_2_facebook_likes       5030 non-null float64
# imdb_score                   5043 non-null int64
# aspect_ratio                 4714 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(12), int64(4), object(12)
# memory usage: 1.1+ MB

# %%
#Columnas numericas y columnas de texto
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                     int64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
#Miramos si es una columna de numeros de punto flotante o no
movies.dtypes == float
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                 False
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                 False
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                 False
# facenumber_in_poster          True
# plot_keywords                False
# movie_imdb_link              False
# num_user_for_reviews          True
# language                     False
# country                      False
# content_rating               False
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
# Si la columna es float o entera
(movies.dtypes == float) | (movies.dtypes == int)
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                 False
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                 False
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                 False
# facenumber_in_poster          True
# plot_keywords                False
# movie_imdb_link              False
# num_user_for_reviews          True
# language                     False
# country                      False
# content_rating               False
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
# Comprobar si es una columna de texto o no
movies.dtypes == object
# Out:
# color                         True
# director_name                 True
# num_critic_for_reviews       False
# duration                     False
# director_facebook_likes      False
# actor_3_facebook_likes       False
# actor_2_name                  True
# actor_1_facebook_likes       False
# gross                        False
# genres                        True
# actor_1_name                  True
# movie_title                   True
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster         False
# plot_keywords                 True
# movie_imdb_link               True
# num_user_for_reviews         False
# language                      True
# country                       True
# content_rating                True
# budget                       False
# title_year                   False
# actor_2_facebook_likes       False
# imdb_score                   False
# aspect_ratio                 False
# movie_facebook_likes         False
# dtype: bool

# %%
num = (movies.dtypes == float) | (movies.dtypes == int)
num
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                 False
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                 False
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                 False
# facenumber_in_poster          True
# plot_keywords                False
# movie_imdb_link              False
# num_user_for_reviews          True
# language                     False
# country                      False
# content_rating               False
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
num.index
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
for el in num.index:
    print(el)
# Out:
# color
# director_name
# num_critic_for_reviews
# duration
# director_facebook_likes
# actor_3_facebook_likes
# actor_2_name
# actor_1_facebook_likes
# gross
# genres
# actor_1_name
# movie_title
# num_voted_users
# cast_total_facebook_likes
# actor_3_name
# facenumber_in_poster
# plot_keywords
# movie_imdb_link
# num_user_for_reviews
# language
# country
# content_rating
# budget
# title_year
# actor_2_facebook_likes
# imdb_score
# aspect_ratio
# movie_facebook_likes

# %%
#Solo las columnas que son numericas
num_cols = [c for c in num.index if num[c]]
num_cols
# Out:
# ['num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_1_facebook_likes',
#  'gross',
#  'facenumber_in_poster',
#  'num_user_for_reviews',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'aspect_ratio']

# %%
movies.dtypes == int
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews       False
# duration                     False
# director_facebook_likes      False
# actor_3_facebook_likes       False
# actor_2_name                 False
# actor_1_facebook_likes       False
# gross                        False
# genres                       False
# actor_1_name                 False
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                 False
# facenumber_in_poster         False
# plot_keywords                False
# movie_imdb_link              False
# num_user_for_reviews         False
# language                     False
# country                      False
# content_rating               False
# budget                       False
# title_year                   False
# actor_2_facebook_likes       False
# imdb_score                   False
# aspect_ratio                 False
# movie_facebook_likes         False
# dtype: bool

# %%
#Solo las que son texto
movies.dtypes == object
obj = (movies.dtypes == object)
cols_obj = [c for c in obj.index if obj[c]]
cols_obj
# Out:
# ['color',
#  'director_name',
#  'actor_2_name',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'actor_3_name',
#  'plot_keywords',
#  'movie_imdb_link',
#  'language',
#  'country',
#  'content_rating']

# %% [markdown]
# ## Inspección cuantitativa y de salud de los datos

# %%
movies_num = movies[num_cols]
movies_num.head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                     NaN       NaN                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                     NaN                   131.0          NaN
#
#    facenumber_in_poster  num_user_for_reviews       budget  title_year  \
# 0                   0.0                3054.0  237000000.0      2009.0
# 1                   0.0                1238.0  300000000.0      2007.0
# 2                   1.0                 994.0  245000000.0      2015.0
# 3                   0.0                2701.0  250000000.0      2012.0
# 4                   0.0                   NaN          NaN         NaN
#
#    actor_2_facebook_likes  aspect_ratio
# 0                   936.0         178.0
# 1                  5000.0         235.0
# 2                   393.0         235.0
# 3                 23000.0         235.0
# 4                    12.0           NaN

# %%
# Estadistica de las columnas númericas
movies_num.describe()

# Count = cuantos valores ahi
# mean = promedio
# std = desviacion estandar
# min = minimo
# 25%, 50%, 75% = cuartiles
# max = maximo
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        facenumber_in_poster  num_user_for_reviews        budget   title_year  \
# count           5030.000000           5022.000000  4.551000e+03  4935.000000
# mean               1.371173            272.770808  3.975262e+07  2002.470517
# std                2.013576            377.982886  2.061149e+08    12.474599
# min                0.000000              1.000000  2.180000e+02  1916.000000
# 25%                0.000000             65.000000  6.000000e+06  1999.000000
# 50%                1.000000            156.000000  2.000000e+07  2005.000000
# 75%                2.000000            326.000000  4.500000e+07  2011.000000
# max               43.000000           5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes  aspect_ratio
# count             5030.000000   4714.000000
# mean              1651.754473    206.720832
# std               4042.438863     32.832970
# min                  0.000000     12.000000
# 25%                281.000000    185.000000
# 50%                595.000000    235.000000
# 75%                918.000000    235.000000
# max             137000.000000    276.000000

# %%
# Ver la informacion en plots
movies_num['duration'].hist()

## Podemos ver que alrededor de 2800 peliculas estan entre los +-70mins y los 120mins
## Y que el promedio de duracion es de 107mins de acuerdo con la tabla descriptiva

# %%
movies_num.columns
# Out:
# Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'facenumber_in_poster', 'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio'],
#       dtype='object')

# %%
movies['imdb_score'].hist()
# movies_num['imdb_score'].hist(log='true') asi podriamos ver en orden logaritmico
# Podemos ver que la mayoria de las peliculas oscilan entre un puntaje de 6.2 y +-7.1
# Por la tabla descriptiva podemos deducir que el promedio de puntaje es de 6.442138

# %%
movies_num['budget'].hist() #Haremos un histogram de el presupuesto

# %% [markdown]
# ##### Aqui se presenta que esta no grafica no tiene una distribucion gaussiana normal,
#
# ##### Que podemos deducir de este histogram
#
# ##### Que todos los valores esta en el primer rango de valores, entre 0.0 y 0.1 multiplicado por $10^{10}$ ($1e10$)
#
# ##### Inferiores al billon de dolares de presupueto, pero si hay pocas que sobrepasan este budget

# %% [markdown]
# *Para poder debuggear esta situación utilizaremos una tecnica muy tipica de pandas que se llama **boolean filtering**. Basicamente construimos una serie de booleanos con el mismo indice que nuestro dataframe(La serie clasicamente la llamaremos mask)*

# %%
#Tomamos la columna problematica y vemos que peliculas superan el budget de el billon de dolares
movies_num['budget'] > 1e9
# Por lo que vemos son muy pocas
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5013    False
# 5014    False
# 5015    False
# 5016    False
# 5017    False
# 5018    False
# 5019    False
# 5020    False
# 5021    False
# 5022    False
# 5023    False
# 5024    False
# 5025    False
# 5026    False
# 5027    False
# 5028    False
# 5029    False
# 5030    False
# 5031    False
# 5032    False
# 5033    False
# 5034    False
# 5035    False
# 5036    False
# 5037    False
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: budget, Length: 5043, dtype: bool

# %%
# Averiguamos cuantas superan el billon contando los trues de la condicion
(movies_num['budget'] > 1e9).value_counts()
# y lo que nos arrojo es que solo existen 6 peliculas que superan el billon de dolares(mil millones)
# Lo que nos hace caer en cuenta que los datos que arroja el histograma no son correctos por estos datos que se salen del scope normal
# por lo tanto se debugean
# Out:
# False    5037
# True        6
# Name: budget, dtype: int64

# %%
# Entonces lo que hacemos es tomar esta serie booleana y la guardamos en una variable para ver que peliculas son las que causan este problema
mask = (movies_num['budget'] > 1e9)
# y le decimos al dataset principal que no muestre estos datos
budget = movies[mask]
budget
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 2323  Color   Hayao Miyazaki                   174.0     134.0
# 2334  Color  Katsuhiro Ôtomo                   105.0     103.0
# 2988  Color     Joon-ho Bong                   363.0     110.0
# 3005  Color     Lajos Koltai                    73.0     134.0
# 3423  Color  Katsuhiro Ôtomo                   150.0     124.0
# 3859  Color   Chan-wook Park                   202.0     112.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2323                   6000.0                   745.0  Jada Pinkett Smith
# 2334                     78.0                   101.0  Robin Atkin Downes
# 2988                    584.0                    74.0        Kang-ho Song
# 3005                     45.0                     0.0     Péter Fancsikai
# 3423                     78.0                     4.0       Takeshi Kusao
# 3859                      0.0                    38.0        Yeong-ae Lee
#
#       actor_1_facebook_likes      gross  \
# 2323                   893.0  2298191.0
# 2334                   488.0   410388.0
# 2988                   629.0  2201412.0
# 3005                     9.0   195888.0
# 3423                     6.0   439162.0
# 3859                   717.0   211667.0
#
#                                                  genres         ...           \
# 2323                        Adventure|Animation|Fantasy         ...
# 2334  Action|Adventure|Animation|Family|Sci-Fi|Thriller         ...
# 2988                         Comedy|Drama|Horror|Sci-Fi         ...
# 3005                                  Drama|Romance|War         ...
# 3423                            Action|Animation|Sci-Fi         ...
# 3859                                        Crime|Drama         ...
#
#      num_user_for_reviews   language      country  content_rating  \
# 2323                570.0   Japanese        Japan           PG-13
# 2334                 79.0   Japanese        Japan           PG-13
# 2988                279.0     Korean  South Korea               R
# 3005                 45.0  Hungarian      Hungary               R
# 3423                430.0   Japanese        Japan               R
# 3859                131.0     Korean  South Korea               R
#
#             budget  title_year actor_2_facebook_likes imdb_score  \
# 2323  2.400000e+09      1997.0                  851.0         84
# 2334  2.127520e+09      2004.0                  336.0         69
# 2988  1.221550e+10      2006.0                  398.0         70
# 3005  2.500000e+09      2005.0                    2.0         71
# 3423  1.100000e+09      1988.0                    5.0         81
# 3859  4.200000e+09      2005.0                  126.0         77
#
#       aspect_ratio movie_facebook_likes
# 2323         185.0                11000
# 2334         185.0                  973
# 2988         185.0                 7000
# 3005         235.0                  607
# 3423         185.0                    0
# 3859         235.0                 4000
#
# [6 rows x 28 columns]

# %%
budget[['movie_title','budget', 'country','language']]
#Con esta informacion nos podemos dirigir a examinar una de las peliculas para saber que esta pasando
# Out:
#             movie_title        budget      country   language
# 2323  Princess Mononoke  2.400000e+09        Japan   Japanese
# 2334           Steamboy  2.127520e+09        Japan   Japanese
# 2988           The Host  1.221550e+10  South Korea     Korean
# 3005           Fateless  2.500000e+09      Hungary  Hungarian
# 3423              Akira  1.100000e+09        Japan   Japanese
# 3859     Lady Vengeance  4.200000e+09  South Korea     Korean

# %% [markdown]
# ![Akira](assets/Akira.png)Podemos ver el que budget en su numero es correcto pero esta en yenes y no en dolares, por lo que tendremos que hacer la conversion

# %%
## Esto es clasico en un dataset, ya que la mayoria de las veces los datos no vienen limpios

# %%
 movies[(movies['country'] == 'USA') | (movies['country'] == 'UK')][['movie_title','country','budget']]
# Out:
#                                       movie_title country       budget
# 0                                          Avatar     USA  237000000.0
# 1        Pirates of the Caribbean: At World's End     USA  300000000.0
# 2                                         Spectre      UK  245000000.0
# 3                           The Dark Knight Rises     USA  250000000.0
# 5                                     John Carter     USA  263700000.0
# 6                                    Spider-Man 3     USA  258000000.0
# 7                                         Tangled     USA  260000000.0
# 8                         Avengers: Age of Ultron     USA  250000000.0
# 9          Harry Potter and the Half-Blood Prince      UK  250000000.0
# 10             Batman v Superman: Dawn of Justice     USA  250000000.0
# 11                               Superman Returns     USA  209000000.0
# 12                              Quantum of Solace      UK  200000000.0
# 13      Pirates of the Caribbean: Dead Mans Chest     USA  225000000.0
# 14                                The Lone Ranger     USA  215000000.0
# 15                                   Man of Steel     USA  225000000.0
# 16       The Chronicles of Narnia: Prince Caspian     USA  225000000.0
# 17                                   The Avengers     USA  220000000.0
# 18    Pirates of the Caribbean: On Stranger Tides     USA  250000000.0
# 19                                 Men in Black 3     USA  225000000.0
# 21                         The Amazing Spider-Man     USA  230000000.0
# 22                                     Robin Hood     USA  200000000.0
# 23            The Hobbit: The Desolation of Smaug     USA  225000000.0
# 24                             The Golden Compass     USA  180000000.0
# 26                                        Titanic     USA  200000000.0
# 27                     Captain America: Civil War     USA  250000000.0
# 28                                     Battleship     USA  209000000.0
# 29                                 Jurassic World     USA  150000000.0
# 30                                        Skyfall      UK  200000000.0
# 31                                   Spider-Man 2     USA  200000000.0
# 32                                     Iron Man 3     USA  200000000.0
# ...                                           ...     ...          ...
# 5004                      The Legend of God's Gun     USA      30000.0
# 5005                          Mutual Appreciation     USA          NaN
# 5006            Her Cry: La Llorona Investigation     USA      60000.0
# 5007                                 Down Terrace      UK          NaN
# 5008                                       Clerks     USA     230000.0
# 5009                               Pink Narcissus     USA      27000.0
# 5010                                  Funny Ha Ha     USA          NaN
# 5012                                     Sabotage     USA   35000000.0
# 5013                                       Manito     USA      24000.0
# 5015                                      Slacker     USA      23000.0
# 5016                                  Dutch Kills     USA      25000.0
# 5017                                    Dry Spell     USA      22000.0
# 5018                                     Flywheel     USA      20000.0
# 5019                                       Exeter     USA          NaN
# 5020                                   The Ridges     USA      17350.0
# 5021                              The Puffy Chair     USA      15000.0
# 5023                             Breaking Upwards     USA      15000.0
# 5024                     All Superheroes Must Die     USA      20000.0
# 5025                               Pink Flamingos     USA      10000.0
# 5030                               On the Downlow     USA          NaN
# 5031                 Sanctuary; Quite a Conundrum     USA     200000.0
# 5032                                         Bang     USA          NaN
# 5033                                       Primer     USA       7000.0
# 5035                                  El Mariachi     USA       7000.0
# 5036                              The Mongol King     USA       3250.0
# 5037                                    Newlyweds     USA       9000.0
# 5039                    The Following                 USA          NaN
# 5040                         A Plague So Pleasant     USA       1400.0
# 5041                             Shanghai Calling     USA          NaN
# 5042                            My Date with Drew     USA       1100.0
#
# [4255 rows x 3 columns]

# %%
print("Vemos que es son pocas peliculas las que tocaria limpiar ya que de solo los paises UK y USA se tienen 4255 peliculas y estan bien y el resto abria que examinarlas")
print("Cantidad total de peliculas:",movies.shape[0])
# Out:
# Vemos que es son pocas peliculas las que tocaria limpiar ya que de solo los paises UK y USA se tienen 4255 peliculas y estan bien y el resto abria que examinarlas
# Cantidad total de peliculas: 5043

# %%
movies_remaster = movies

# %%
movies_fix = movies_remaster[(movies_remaster.country != 'USA') & (movies_remaster.country != 'UK')]
movies_remaster[(movies_remaster.country != 'USA') & (movies_remaster.country != 'UK')].shape
# Out:
# (788, 28)

# %%
movies_fix.groupby('country')['country'].count().sort_values(ascending=False)
# Out:
# country
# France                  154
# Canada                  126
# Germany                  97
# Australia                55
# India                    34
# Spain                    33
# China                    30
# Italy                    23
# Japan                    23
# Hong Kong                17
# Mexico                   17
# New Zealand              15
# South Korea              14
# Ireland                  12
# Russia                   11
# Denmark                  11
# Norway                    8
# Brazil                    8
# South Africa              8
# Sweden                    6
# Netherlands               5
# Poland                    5
# Thailand                  5
# Romania                   4
# Belgium                   4
# Iran                      4
# Argentina                 4
# Israel                    4
# Iceland                   3
# Czech Republic            3
#                        ...
# Hungary                   2
# Greece                    2
# United Arab Emirates      1
# Cambodia                  1
# Slovakia                  1
# Chile                     1
# Slovenia                  1
# Cameroon                  1
# Soviet Union              1
# Bulgaria                  1
# Philippines               1
# Bahamas                   1
# Aruba                     1
# Turkey                    1
# Colombia                  1
# Peru                      1
# Kenya                     1
# Dominican Republic        1
# Egypt                     1
# Finland                   1
# Panama                    1
# Georgia                   1
# Pakistan                  1
# Official site             1
# Nigeria                   1
# New Line                  1
# Indonesia                 1
# Libya                     1
# Kyrgyzstan                1
# Afghanistan               1
# Name: country, Length: 63, dtype: int64

# %%
#Podemos concluir que debemos arreglar 63 paises por su tipo de moneda probablemente, cabe aclarar que muchos pueden estar en dolares

# %%
#curoseando un poco
print(movies.query('country == "Colombia"')['movie_title'])
movies.loc[4043,:]
# Out:
# 4043    Maria Full of Grace
# Name: movie_title, dtype: object
# color                                                                    Color
# director_name                                                   Joshua Marston
# num_critic_for_reviews                                                     155
# duration                                                                   101
# director_facebook_likes                                                     13
# actor_3_facebook_likes                                                       6
# actor_2_name                                                   Wilson Guerrero
# actor_1_facebook_likes                                                     280
# gross                                                               6.5172e+06
# genres                                                             Crime|Drama
# actor_1_name                                           Catalina Sandino Moreno
# movie_title                                                Maria Full of Grace
# num_voted_users                                                          30474
# cast_total_facebook_likes                                                  308
# actor_3_name                                                  Yenny Paola Vega
# facenumber_in_poster                                                         0
# plot_keywords                       colombia|colombian|drug mule|money|stomach
# movie_imdb_link              http://www.imdb.com/title/tt0390221/?ref_=fn_t...
# num_user_for_reviews                                                       172
# language                                                               Spanish
# country                                                               Colombia
# content_rating                                                               R
# budget                                                                   3e+06
# title_year                                                                2004
# actor_2_facebook_likes                                                      11
# imdb_score                                                                  75
# aspect_ratio                                                               185
# movie_facebook_likes                                                         0
# Name: 4043, dtype: object

# %%
movies.query('country == "France"')[['movie_title','budget']]
# Out:
#                                   movie_title       budget
# 242              Asterix at the Olympic Games   78000000.0
# 322                                Green Zone  100000000.0
# 332                         The Fifth Element   93000000.0
# 489                                 Evolution          NaN
# 503                 Arthur and the Invisibles   86000000.0
# 504                                    Oceans   40000000.0
# 516                         The Little Prince   81200000.0
# 545                                    Munich   70000000.0
# 578                              Two Brothers   59660000.0
# 677                            Primary Colors   65000000.0
# 687                             Lucky Numbers   65000000.0
# 702                                     U-571   62000000.0
# 889                    A Very Long Engagement   47000000.0
# 921                      From Paris with Love   52000000.0
# 999                                 Assassins   50000000.0
# 1016  The Messenger: The Story of Joan of Arc  390000000.0
# 1024                                   Domino   50000000.0
# 1053                                  Taken 3   48000000.0
# 1074                                  Taken 2   45000000.0
# 1103                Resident Evil: Extinction   45000000.0
# 1116                             Babylon A.D.   70000000.0
# 1126                         The Ghost Writer   45000000.0
# 1133                 The Returned                      NaN
# 1149                                Unleashed   45000000.0
# 1176                                  Micmacs   27000000.0
# 1178             Animal Kingdom: Let's go Ape          NaN
# 1189                                     Lucy   40000000.0
# 1217                                      JFK   40000000.0
# 1283                               Colombiana   40000000.0
# 1289                                Showgirls   45000000.0
# ...                                       ...          ...
# 3860                          Mozart's Sister          NaN
# 3905                The Last Exorcism Part II    5000000.0
# 3937                              Holy Motors          NaN
# 4024                    March of the Penguins    8000000.0
# 4039                                The Class          NaN
# 4151                             High Tension    2200000.0
# 4258                             Silent House    2000000.0
# 4263               The Triplets of Belleville    9500000.0
# 4276        Ghost Dog: The Way of the Samurai          NaN
# 4295                                   Subway   17000000.0
# 4349                           One to Another    1400000.0
# 4356                        The Last Exorcism    1800000.0
# 4393                                  Caramel    1300000.0
# 4398                      Mississippi Mermaid    1600000.0
# 4419                              Killing Zoe    1500000.0
# 4455                            The Blue Room          NaN
# 4504                                        Q    1500000.0
# 4644                             Circumstance          NaN
# 4651                                     Elza     900000.0
# 4663                    Raising Victor Vargas     800000.0
# 4667                               Deterrence     800000.0
# 4717                            Irreplaceable          NaN
# 4751                                   Rubber     500000.0
# 4814                                   Maniac    6000000.0
# 4829                      When the Cat's Away     300000.0
# 4835                           Pierrot le Fou     300000.0
# 4848                                  Bizarre     500000.0
# 4911             The Case of the Grinning Cat     150000.0
# 4952                         Une Femme Mariée     120000.0
# 5026                                    Clean       4500.0
#
# [154 rows x 2 columns]

# %% [markdown]
# Estudiando este grupo de peliculas de francia la moneda en la que esta el budget no es homogenea por lo que abri que hacerle una limpieza manual

# %% [markdown]
# ## Limpiar los datos

# %%
# importamos DB thenumbers.com Ahora manejaremos los datos faltantes (nulos o NaN)
financials = pd.read_csv('thenumbers.csv', encoding='utf-8', delimiter=';')
financials.head()
# Out:
#   Release Date                                  movie_title  \
# 0   12/18/2009                                       Avatar
# 1    5/20/2011  Pirates of the Caribbean: On Stranger Tides
# 2     5/1/2015                      Avengers: Age of Ultron
# 3   12/18/2015         Star Wars Ep. VII: The Force Awakens
# 4    5/24/2007     Pirates of the Caribbean: At World’s End
#
#    Production Budget  Domestic Gross  Worldwide Gross
# 0        425000000.0       760507625       2783918982
# 1        410600000.0       241063875       1045663875
# 2        330600000.0       459005868       1408218722
# 3        306000000.0       936662225       2058662225
# 4        300000000.0       309420425        963420425

# %%
financials.columns
# Out:
# Index(['Release Date', 'movie_title', 'Production Budget', 'Domestic Gross',
#        'Worldwide Gross'],
#       dtype='object')

# %%
#Escojemos solo las columnas que con las que trabajaremos
financials = financials[['movie_title','Production Budget','Worldwide Gross']]
financials.head()
# Out:
#                                    movie_title  Production Budget  \
# 0                                       Avatar        425000000.0
# 1  Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                      Avengers: Age of Ultron        330600000.0
# 3         Star Wars Ep. VII: The Force Awakens        306000000.0
# 4     Pirates of the Caribbean: At World’s End        300000000.0
#
#    Worldwide Gross
# 0       2783918982
# 1       1045663875
# 2       1408218722
# 3       2058662225
# 4        963420425

# %%
financials.shape
# Out:
# (5435, 3)

# %%
movies_num.shape
# Out:
# (5043, 13)

# %% [markdown]
# Perderemos datos pero es en pro de tener datos de calidad

# %% [markdown]
# ## Combinamos nuestras tablas

# %%
# Agregamos la columna title a nuestro dataframe movies_num, para utilizarla de llave para conectar el otro dataframe
#concatenamos
movies_num = pd.concat([movies_num,movies['movie_title']],axis=1)
movies_num.head()
#Podemos ver que ya se añadido la columna a nuestro dataframe
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                     NaN       NaN                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                     NaN                   131.0          NaN
#
#    facenumber_in_poster  num_user_for_reviews       budget  title_year  \
# 0                   0.0                3054.0  237000000.0      2009.0
# 1                   0.0                1238.0  300000000.0      2007.0
# 2                   1.0                 994.0  245000000.0      2015.0
# 3                   0.0                2701.0  250000000.0      2012.0
# 4                   0.0                   NaN          NaN         NaN
#
#    actor_2_facebook_likes  aspect_ratio  \
# 0                   936.0         178.0
# 1                  5000.0         235.0
# 2                   393.0         235.0
# 3                 23000.0         235.0
# 4                    12.0           NaN
#
#                                          movie_title
# 0                                             Avatar
# 1           Pirates of the Caribbean: At World's End
# 2                                            Spectre
# 3                              The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...

# %%
#Haremos el merge de el dataframe movies_num con el de financials
movies_v2 = pd.merge(financials,movies_num,on='movie_title',how='left')
#Por lo que le hicimos un merge y se conserva la informacion de movies_num, y se pasa la de financials
movies_v2.shape
# Out:
# (5614, 15)

# %%
movies_v2.head(50)
# Out:
#                                          movie_title  Production Budget  \
# 0                                             Avatar        425000000.0
# 1        Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                            Avengers: Age of Ultron        330600000.0
# 3               Star Wars Ep. VII: The Force Awakens        306000000.0
# 4           Pirates of the Caribbean: At World’s End        300000000.0
# 5                                            Spectre        300000000.0
# 6                              The Dark Knight Rises        275000000.0
# 7                                    The Lone Ranger        275000000.0
# 8                                        John Carter        275000000.0
# 9                                            Tangled        260000000.0
# 10                                      Spider-Man 3        258000000.0
# 11                                      Spider-Man 3        258000000.0
# 12                        Captain America: Civil War        250000000.0
# 13                Batman v Superman: Dawn of Justice        250000000.0
# 14                 The Hobbit: An Unexpected Journey        250000000.0
# 15            Harry Potter and the Half-Blood Prince        250000000.0
# 16               The Hobbit: The Desolation of Smaug        250000000.0
# 17         The Hobbit: The Battle of the Five Armies        250000000.0
# 18                           The Fate of the Furious        250000000.0
# 19                                  Superman Returns        232000000.0
# 20  Pirates of the Caribbean: Dead Men Tell No Tales        230000000.0
# 21                                 Quantum of Solace        230000000.0
# 22                                      The Avengers        225000000.0
# 23                                      The Avengers        225000000.0
# 24        Pirates of the Caribbean: Dead Man’s Chest        225000000.0
# 25                                      Man of Steel        225000000.0
# 26          The Chronicles of Narnia: Prince Caspian        225000000.0
# 27                            The Amazing Spider-Man        220000000.0
# 28                     Transformers: The Last Knight        217000000.0
# 29                                    Jurassic World        215000000.0
# 30                                    Men in Black 3        215000000.0
# 31               Transformers: Revenge of the Fallen        210000000.0
# 32                   Transformers: Age of Extinction        210000000.0
# 33                             X-Men: The Last Stand        210000000.0
# 34                                        Robin Hood        210000000.0
# 35                                        Battleship        209000000.0
# 36                                         King Kong        207000000.0
# 37                                         King Kong        207000000.0
# 38                                         King Kong        207000000.0
# 39                                The Golden Compass        205000000.0
# 40                                           Titanic        200000000.0
# 41                      Rogue One: A Star Wars Story        200000000.0
# 42                                      Finding Dory        200000000.0
# 43                                       Toy Story 3        200000000.0
# 44                                        Iron Man 3        200000000.0
# 45                     Guardians of the Galaxy Vol 2        200000000.0
# 46                                      Spider-Man 2        200000000.0
# 47                               Alice in Wonderland        200000000.0
# 48                               Alice in Wonderland        200000000.0
# 49                                           Skyfall        200000000.0
#
#     Worldwide Gross  num_critic_for_reviews  duration  \
# 0        2783918982                   723.0     178.0
# 1        1045663875                   448.0     136.0
# 2        1408218722                   635.0     141.0
# 3        2058662225                     NaN       NaN
# 4         963420425                     NaN       NaN
# 5         879620923                   602.0     148.0
# 6        1084439099                   813.0     164.0
# 7         260002115                   450.0     150.0
# 8         282778100                   462.0     132.0
# 9         586581936                   324.0     100.0
# 10        894860230                   392.0     156.0
# 11        894860230                   392.0     156.0
# 12       1153304495                   516.0     147.0
# 13        868160194                   673.0     183.0
# 14       1017003568                   645.0     182.0
# 15        935083686                   375.0     153.0
# 16        960366855                   509.0     186.0
# 17        955119788                   422.0     164.0
# 18       1237444462                     NaN       NaN
# 19        374085065                   434.0     169.0
# 20        784610092                     NaN       NaN
# 21        591692078                   403.0     106.0
# 22       1519479547                   703.0     173.0
# 23       1519479547                   703.0     173.0
# 24       1066215812                     NaN       NaN
# 25        667999518                   733.0     143.0
# 26        417341288                   258.0     150.0
# 27        757890267                   599.0     153.0
# 28        603968683                     NaN       NaN
# 29       1671640593                   644.0     124.0
# 30        654213485                   451.0     106.0
# 31        836519699                   366.0     150.0
# 32       1104039076                   378.0     165.0
# 33        459260946                   334.0     104.0
# 34        322241588                   343.0     156.0
# 35        305218228                   377.0     131.0
# 36        550517357                   446.0     201.0
# 37        550517357                   446.0     201.0
# 38        550517357                   446.0     201.0
# 39        367262558                   251.0     113.0
# 40       2207615668                   315.0     194.0
# 41       1050988488                     NaN       NaN
# 42       1022617376                     NaN       NaN
# 43       1069818229                   453.0     103.0
# 44       1215392272                   608.0     195.0
# 45        860477263                     NaN       NaN
# 46        795110670                   300.0     135.0
# 47       1025491110                   451.0     108.0
# 48       1025491110                   451.0     108.0
# 49       1110526981                   750.0     143.0
#
#     director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                       0.0                   855.0                  1000.0
# 1                     252.0                  1000.0                 40000.0
# 2                       0.0                 19000.0                 26000.0
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# 5                       0.0                   161.0                 11000.0
# 6                   22000.0                 23000.0                 27000.0
# 7                     563.0                  1000.0                 40000.0
# 8                     475.0                   530.0                   640.0
# 9                      15.0                   284.0                   799.0
# 10                      0.0                  4000.0                 24000.0
# 11                      0.0                  4000.0                 24000.0
# 12                     94.0                 11000.0                 21000.0
# 13                      0.0                  2000.0                 15000.0
# 14                      0.0                   773.0                  5000.0
# 15                    282.0                 10000.0                 25000.0
# 16                      0.0                   773.0                  5000.0
# 17                      0.0                   773.0                  5000.0
# 18                      NaN                     NaN                     NaN
# 19                      0.0                   903.0                 18000.0
# 20                      NaN                     NaN                     NaN
# 21                    395.0                   393.0                   451.0
# 22                      0.0                 19000.0                 26000.0
# 23                      0.0                 19000.0                 26000.0
# 24                      NaN                     NaN                     NaN
# 25                      0.0                   748.0                 15000.0
# 26                     80.0                   201.0                 22000.0
# 27                    464.0                   963.0                 15000.0
# 28                      NaN                     NaN                     NaN
# 29                    365.0                  1000.0                  3000.0
# 30                    188.0                   718.0                 10000.0
# 31                      0.0                   464.0                   894.0
# 32                      0.0                   808.0                   974.0
# 33                    420.0                   560.0                 20000.0
# 34                      0.0                   738.0                   891.0
# 35                    532.0                   627.0                 14000.0
# 36                      0.0                    84.0                  6000.0
# 37                      0.0                    84.0                  6000.0
# 38                      0.0                    84.0                  6000.0
# 39                    129.0                  1000.0                 16000.0
# 40                      0.0                   794.0                 29000.0
# 41                      NaN                     NaN                     NaN
# 42                      NaN                     NaN                     NaN
# 43                    125.0                   721.0                 15000.0
# 44                   1000.0                  3000.0                 21000.0
# 45                      NaN                     NaN                     NaN
# 46                      0.0                  4000.0                 24000.0
# 47                  13000.0                 11000.0                 40000.0
# 48                  13000.0                 11000.0                 40000.0
# 49                      0.0                   393.0                   883.0
#
#           gross  facenumber_in_poster  num_user_for_reviews       budget  \
# 0   760505847.0                   0.0                3054.0  237000000.0
# 1   241063875.0                   4.0                 484.0  250000000.0
# 2   458991599.0                   4.0                1117.0  250000000.0
# 3           NaN                   NaN                   NaN          NaN
# 4           NaN                   NaN                   NaN          NaN
# 5   200074175.0                   1.0                 994.0  245000000.0
# 6   448130642.0                   0.0                2701.0  250000000.0
# 7    89289910.0                   1.0                 711.0  215000000.0
# 8    73058679.0                   1.0                 738.0  263700000.0
# 9   200807262.0                   1.0                 387.0  260000000.0
# 10  336530303.0                   0.0                1902.0  258000000.0
# 11  336530303.0                   0.0                1902.0  258000000.0
# 12  407197282.0                   0.0                1022.0  250000000.0
# 13  330249062.0                   0.0                3018.0  250000000.0
# 14  303001229.0                   NaN                1367.0  180000000.0
# 15  301956980.0                   3.0                 973.0  250000000.0
# 16  258355354.0                   6.0                 951.0  225000000.0
# 17  255108370.0                   0.0                 802.0  250000000.0
# 18          NaN                   NaN                   NaN          NaN
# 19  200069408.0                   0.0                2367.0  209000000.0
# 20          NaN                   NaN                   NaN          NaN
# 21  168368427.0                   1.0                1243.0  200000000.0
# 22  623279547.0                   3.0                1722.0  220000000.0
# 23  623279547.0                   3.0                1722.0  220000000.0
# 24          NaN                   NaN                   NaN          NaN
# 25  291021565.0                   0.0                2536.0  225000000.0
# 26  141614023.0                   4.0                 438.0  225000000.0
# 27  262030663.0                   0.0                1225.0  230000000.0
# 28          NaN                   NaN                   NaN          NaN
# 29  652177271.0                   0.0                1290.0  150000000.0
# 30  179020854.0                   1.0                 341.0  225000000.0
# 31  402076689.0                   0.0                1439.0  200000000.0
# 32  245428137.0                   2.0                 918.0  210000000.0
# 33  234360014.0                   0.0                1912.0  210000000.0
# 34  105219735.0                   0.0                 546.0  200000000.0
# 35   65173160.0                   0.0                 751.0  209000000.0
# 36  218051260.0                   0.0                2618.0  207000000.0
# 37  218051260.0                   0.0                2618.0  207000000.0
# 38  218051260.0                   0.0                2618.0  207000000.0
# 39   70083519.0                   2.0                 666.0  180000000.0
# 40  658672302.0                   0.0                2528.0  200000000.0
# 41          NaN                   NaN                   NaN          NaN
# 42          NaN                   NaN                   NaN          NaN
# 43  414984497.0                   3.0                 733.0  200000000.0
# 44  408992272.0                   3.0                1187.0  200000000.0
# 45          NaN                   NaN                   NaN          NaN
# 46  373377893.0                   1.0                1303.0  200000000.0
# 47  334185206.0                   0.0                 736.0  200000000.0
# 48  334185206.0                   0.0                 736.0  200000000.0
# 49  304360277.0                   0.0                1498.0  200000000.0
#
#     title_year  actor_2_facebook_likes  aspect_ratio
# 0       2009.0                   936.0         178.0
# 1       2011.0                 11000.0         235.0
# 2       2015.0                 21000.0         235.0
# 3          NaN                     NaN           NaN
# 4          NaN                     NaN           NaN
# 5       2015.0                   393.0         235.0
# 6       2012.0                 23000.0         235.0
# 7       2013.0                  2000.0         235.0
# 8       2012.0                   632.0         235.0
# 9       2010.0                   553.0         185.0
# 10      2007.0                 11000.0         235.0
# 11      2007.0                 11000.0         235.0
# 12      2016.0                 19000.0         235.0
# 13      2016.0                  4000.0         235.0
# 14      2012.0                   972.0         235.0
# 15      2009.0                 11000.0         235.0
# 16      2013.0                   972.0         235.0
# 17      2014.0                   972.0         235.0
# 18         NaN                     NaN           NaN
# 19      2006.0                 10000.0         235.0
# 20         NaN                     NaN           NaN
# 21      2008.0                   412.0         235.0
# 22      2012.0                 21000.0         185.0
# 23      2012.0                 21000.0         185.0
# 24         NaN                     NaN           NaN
# 25      2013.0                  3000.0         235.0
# 26      2008.0                   216.0         235.0
# 27      2012.0                 10000.0         235.0
# 28         NaN                     NaN           NaN
# 29      2015.0                  2000.0          20.0
# 30      2012.0                   816.0         185.0
# 31      2009.0                   581.0         235.0
# 32      2014.0                   956.0         235.0
# 33      2006.0                   808.0         235.0
# 34      2010.0                   882.0         235.0
# 35      2012.0                 10000.0         235.0
# 36      2005.0                   919.0         235.0
# 37      2005.0                   918.0         235.0
# 38      2005.0                   918.0         235.0
# 39      2007.0                  6000.0         235.0
# 40      1997.0                 14000.0         235.0
# 41         NaN                     NaN           NaN
# 42         NaN                     NaN           NaN
# 43      2010.0                  1000.0         185.0
# 44      2013.0                  4000.0         235.0
# 45         NaN                     NaN           NaN
# 46      2004.0                 11000.0         235.0
# 47      2010.0                 25000.0         185.0
# 48      2010.0                 25000.0         185.0
# 49      2012.0                   563.0         235.0

# %%
movies_v2.columns
# Out:
# Index(['movie_title', 'Production Budget', 'Worldwide Gross',
#        'num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'facenumber_in_poster', 'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio'],
#       dtype='object')

# %% [markdown]
# ## Manejo de datos faltantes

# %%
movies_v2 = movies_v2.drop_duplicates('movie_title') 
#REmovemos nombres duplicados

# %% [markdown]
# **Los datos faltantes generan problemas con muchos algoritmos de ML. Es por esto que existen distintas estrategias para lidiar con ellos.**

# %%
## Para pedir ayuda con un comando podemos hacer algo asi
help(pd.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
#     Returns object containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : boolean, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : boolean, default True
#         Sort by values
#     ascending : boolean, default False
#         Sort in ascending order
#     bins : integer, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for pd.cut, only works with numeric data
#     dropna : boolean, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
#     counts : Series

# %%
movies_v2.notnull().apply(pd.Series.value_counts)
# Aplicamos es como un for que va columna por columna contando cuantos valores faltan
# Out:
#        movie_title  Production Budget  Worldwide Gross  \
# False          NaN                418              NaN
# True        5362.0               4944           5362.0
#
#        num_critic_for_reviews  duration  director_facebook_likes  \
# False                    1213      1192                     1182
# True                     4149      4170                     4180
#
#        actor_3_facebook_likes  actor_1_facebook_likes  gross  \
# False                    1195                    1187   1787
# True                     4167                    4175   3575
#
#        facenumber_in_poster  num_user_for_reviews  budget  title_year  \
# False                  1190                  1193    1474        1182
# True                   4172                  4169    3888        4180
#
#        actor_2_facebook_likes  aspect_ratio
# False                    1188          1426
# True                     4174          3936

# %% [markdown]
# ##### Podemos ver entonces que movie title no tiene ningun dato null mientras que Production Budget tiene 418 nulls

# %%
(movies_v2 != 0).apply(pd.Series.value_counts)
# Out:
#        movie_title  Production Budget  Worldwide Gross  \
# False          NaN                NaN              351
# True        5362.0             5362.0             5011
#
#        num_critic_for_reviews  duration  director_facebook_likes  \
# False                     NaN       NaN                      747
# True                   5362.0    5362.0                     4615
#
#        actor_3_facebook_likes  actor_1_facebook_likes   gross  \
# False                      62                      18     NaN
# True                     5300                    5344  5362.0
#
#        facenumber_in_poster  num_user_for_reviews  budget  title_year  \
# False                  1747                   NaN     NaN         NaN
# True                   3615                5362.0  5362.0      5362.0
#
#        actor_2_facebook_likes  aspect_ratio
# False                      44           NaN
# True                     5318        5362.0

# %% [markdown]
# #### Podemos ver cuantos valores son cero y cuantos no

# %% [markdown]
# No podremos entrenar nuestro con datos cuya variable
# objetivo no esta definida o sea nula(valor falso). Eliminemos esas líneas.

# %%
available = ((movies_v2 != 0) & (movies_v2.notnull())) 
available.head()
# Out:
#    movie_title  Production Budget  Worldwide Gross  num_critic_for_reviews  \
# 0         True               True             True                    True
# 1         True               True             True                    True
# 2         True               True             True                    True
# 3         True               True             True                   False
# 4         True               True             True                   False
#
#    duration  director_facebook_likes  actor_3_facebook_likes  \
# 0      True                    False                    True
# 1      True                     True                    True
# 2      True                    False                    True
# 3     False                    False                   False
# 4     False                    False                   False
#
#    actor_1_facebook_likes  gross  facenumber_in_poster  num_user_for_reviews  \
# 0                    True   True                 False                  True
# 1                    True   True                  True                  True
# 2                    True   True                  True                  True
# 3                   False  False                 False                 False
# 4                   False  False                 False                 False
#
#    budget  title_year  actor_2_facebook_likes  aspect_ratio
# 0    True        True                    True          True
# 1    True        True                    True          True
# 2    True        True                    True          True
# 3   False       False                   False         False
# 4   False       False                   False         False

# %%
#Miramos linea por linea si es true o no
available.all(axis=1).value_counts()
# Out:
# False    3776
# True     1586
# dtype: int64

# %%
available.columns
# Out:
# Index(['movie_title', 'Production Budget', 'Worldwide Gross',
#        'num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'facenumber_in_poster', 'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio'],
#       dtype='object')

# %%
mask = available['Worldwide Gross']

# %%
movies_v2 = movies_v2[mask]

# %%
movies_v2['Worldwide Gross'].notnull().value_counts()
# Out:
# True    5011
# Name: Worldwide Gross, dtype: int64
